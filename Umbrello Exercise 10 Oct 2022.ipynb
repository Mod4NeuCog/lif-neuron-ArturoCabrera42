# %% [markdown]
# Introduction to Programming, 10 October 2022. Whole code generated by Umbrello.

# %%
# Class 10 Oct 2022
# Collection of codes generated by Umbrello

class NeuronalCell:



    
    MembranePotential = float



    def computePotential(self):
        """
     

        @return double :
        @author
        """
    pass

    def did_it_fire(self):
        """


        @return bool :
        @author
        """
    pass

from NeuronalCell import *

class PyramidalNeuron (NeuronalCell):

   

  cellOrganelle 



from NeuronalCell import *


class OvoidNeuron (NeuronalCell):


   

  isItsMyelinated
